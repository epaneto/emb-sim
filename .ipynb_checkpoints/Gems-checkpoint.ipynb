# %%
from Gems import Gems

# %%
#first parameter number of players, second parameter chest limit (required for more than one player, so the arrays have the same size)
game = Gems(1)
# Out:
# player completed 577
# average sessions :  577.0
# average days :  192.33333333333334
# average time to complete one set :  19.0
# useless gems:  197.0

# %%
import numpy as np
import pandas as pandaInstance
        

gemHistory = {}

index = 1

for i in game.players:
    key = "player"+ str(index)
    index += 1
    gemHistory[key] = i.gemCountHistory
    
gemDataFrame = pandaInstance.DataFrame(gemHistory)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots(figsize=(15,10))  # Create a figure and an axes.


ax.plot(game.players[0].sessionHistory, gemDataFrame.mean(axis = 1), label='Weapon Skills ACquired')  # Plot some data on the axes.


ax.set_xlabel('Battles')  # Add an x-label to the axes.
ax.set_ylabel('Skills')  # Add a y-label to the axes.
ax.set_title("Average Skills acquired")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
import numpy as np
import pandas as pandaInstance
        

uselessHistory = {}

index = 1

for i in game.players:
    key = "player"+ str(index)
    index += 1
    uselessHistory[key] = i.uselessGemsHistory
    
uselessDataFrame = pandaInstance.DataFrame(uselessHistory)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots(figsize=(15,10))  # Create a figure and an axes.


ax.plot(game.players[0].sessionHistory, uselessDataFrame.mean(axis = 1), label='Useless Gems attempts accumulated')  # Plot some data on the axes.


ax.set_xlabel('Battles')  # Add an x-label to the axes.
ax.set_ylabel('Gems')  # Add a y-label to the axes.
ax.set_title("Attempts with useless gems")  # Add a title to the axes.
ax.legend()  # Add a legend.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-516442c83621> in <module>
#       8
#       9
# ---> 10 ax.plot(game.players[0].sessionHistory, uselessDataFrame.mean(axis = 1), label='Useless Gems attempts accumulated')  # Plot some data on the axes.
#      11
#      12
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (577,) and (0,)
